# %% [markdown]
# <a href="https://colab.research.google.com/github/JozefSL/pyNotes/blob/main/EIA/PacificStorageWklyChanges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import requests

# %%
from google.colab import userdata
api_key = userdata.get('api_key')

# %%
url = 'https://api.eia.gov/v2/natural-gas/stor/wkly/data/?api_key='+ api_key + '&frequency=weekly&data[0]=value&start=2019-01-01&sort[0][column]=period&sort[0][direction]=asc&facets[series][]='

# %%
response = requests.get(url + 'NW2_EPG0_SWO_R31_BCF')

# %%
df = pd.DataFrame(response.json().get('response').get('data'))[['period','value']]
df.columns = ['Period', 'value']
df['Period'] = df['Period'].apply(pd.to_datetime)
df.value = (df.value.astype('Int64')/1).astype('Int64')
df['year'] = df['Period'].dt.year
df['week'] = df['Period'].dt.isocalendar().week
df['change'] = df['value'] - df['value'].shift(1)

df.tail(3)
# Out:
#         Period  value  year  week  change
# 297 2024-09-13    802  2024    37      22
# 298 2024-09-20    818  2024    38      16
# 299 2024-09-27    846  2024    39      28

# %%
ty = df.year.iloc[-1]
ly = ty-1

# %%
dfA = df.pivot(index='week', columns='year', values='change').astype('Int64') #.reset_index(drop='true')
dfA = dfA.drop(dfA.index[-1]).reset_index()  #eliminate the add years with 53 weeks

# %%
dfA.tail(3)
# Out:
# year  week  2019  2020  2021  2022  2023  2024
# 47      48    -3     0   -24    -6   -39  <NA>
# 48      49   -24   -19   -25   -12   -19  <NA>
# 49      50   -29   -34    -9   -33   -23  <NA>
# 50      51   -42   -37   -32   -42   -29  <NA>
# 51      52   -25   -34   -10   -56    -6  <NA>

# %%
dfAA = pd.DataFrame(dfA.iloc[:, -6:-1].mean(axis=1))
dfAA.columns = ['5yAvg']
dfAA['5yMin'] = dfA.iloc[:, -6:-1].min(axis=1) # Actual minimum, also used to calculate stack area bottom
dfAA['5yMaxA'] = dfA.iloc[:, -6:-1].max(axis=1) # Actual maximum, also used to calculate stack area top
dfAA['5yMax'] = dfAA['5yMaxA']-dfAA['5yMin']
#dfAA['10yAvg'] = dfA.iloc[:, -11:-1].mean(axis=1)
#dfAA['10yMin'] = dfA.iloc[:, -11:-1].min(axis=1)
#dfAA['10yMax'] = dfA.iloc[:, -11:-1].max(axis=1)
dfAA['week'] = dfA['week']

# %%
dfAA.head(3)
# Out:
#    5yAvg  5yMin  5yMaxA  5yMax  week
# 0  -20.5    -39       9     48     1
# 1  -43.4    -61     -31     30     2
# 2  -42.4    -60     -20     40     3

# %%
dfA['weekDate'] = pd.to_datetime(str(pd.Timestamp.now().year)+dfA['week'].astype(str)+'5',format='%Y%W%w')
dfAA['weekDate'] = pd.to_datetime(str(pd.Timestamp.now().year)+dfAA['week'].astype(str)+'5',format='%Y%W%w')

# %%
categories = dfAA['weekDate']
lower_bounds = dfAA['5yMin']
upper_bounds = dfAA['5yMaxA']

# %%
fig = go.Figure()

for i in range(len(categories)):
    fig.add_trace(go.Bar(
        x=[categories[i]],
        y=[upper_bounds[i] - lower_bounds[i]],
        base=[lower_bounds[i]],
        marker=dict(color='lightgrey'),
        showlegend=False
        #color_discrete_sequence=['blue']
        #name=str(categories[i])
    ))

fig.add_scatter(x=dfAA.weekDate, y=dfAA['5yAvg'], mode='markers', name='5yAvg', line=dict(color='grey', width=2))
fig.add_scatter(x=dfA.weekDate, y=dfA[ly], mode='markers', name=str(ly),line=dict(color='blue', width=2))
fig.add_scatter(x=dfA.weekDate, y=dfA[ty], mode='lines+markers', name=str(ty),line=dict(color='red', width=3), marker=dict(color='red'))

fig.add_scatter(x = [dfA['weekDate'][dfA[ty].isna().idxmax()-1]], y = [dfA[ty][dfA[ty].isna().idxmax()-1]],
                     mode = 'markers + text',
                     marker = {'color':'red', 'size':14},
                     showlegend = False,
                     text = [dfA[ty][dfA[ty].isna().idxmax()-1]],
                     textfont=dict(color='red', size=16),
                     textposition='top right') # top, bottom, middle

fig.update_layout(autosize=False,width=1200, height=700,
    title={
        'text': '<b>East Region Working Inventory Weekly Changes</b>',
        'font': {'size': 28, 'family': 'Arial', 'color': 'black'}
        },
    #xaxis_title='Week',
    yaxis_title='East Region Working Inventory Weekly Change (Bcf)')

# Add source link as an annotation
fig.add_annotation(
    text="Source: EIA     https://ir.eia.gov/ngs/ngs.html",
    xref="paper", yref="paper",
    x=0.95, y=0.05,
    showarrow=False,
    font=dict(size=13)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2cfa8cb1-cff6-4533-9612-fffce06cfd5f" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cfa8cb1-cff6-4533-9612-fffce06cfd5f")) {                    Plotly.newPlot(                        "2cfa8cb1-cff6-4533-9612-fffce06cfd5f",                        [{"base":[-39],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-05T00:00:00"],"y":[48],"type":"bar"},{"base":[-61],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-12T00:00:00"],"y":[30],"type":"bar"},{"base":[-60],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-19T00:00:00"],"y":[40],"type":"bar"},{"base":[-68],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-26T00:00:00"],"y":[29],"type":"bar"},{"base":[-59],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-02T00:00:00"],"y":[19],"type":"bar"},{"base":[-50],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-09T00:00:00"],"y":[26],"type":"bar"},{"base":[-61],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-16T00:00:00"],"y":[42],"type":"bar"},{"base":[-43],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-23T00:00:00"],"y":[15],"type":"bar"},{"base":[-43],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-01T00:00:00"],"y":[10],"type":"bar"},{"base":[-49],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-08T00:00:00"],"y":[27],"type":"bar"},{"base":[-36],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-15T00:00:00"],"y":[22],"type":"bar"},{"base":[-20],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-22T00:00:00"],"y":[20],"type":"bar"},{"base":[-27],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-29T00:00:00"],"y":[25],"type":"bar"},{"base":[-12],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-05T00:00:00"],"y":[22],"type":"bar"},{"base":[9],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-12T00:00:00"],"y":[10],"type":"bar"},{"base":[-6],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-19T00:00:00"],"y":[33],"type":"bar"},{"base":[5],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-26T00:00:00"],"y":[23],"type":"bar"},{"base":[12],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-03T00:00:00"],"y":[9],"type":"bar"},{"base":[11],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-10T00:00:00"],"y":[25],"type":"bar"},{"base":[17],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-17T00:00:00"],"y":[14],"type":"bar"},{"base":[20],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-24T00:00:00"],"y":[15],"type":"bar"},{"base":[30],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-31T00:00:00"],"y":[2],"type":"bar"},{"base":[16],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-07T00:00:00"],"y":[15],"type":"bar"},{"base":[23],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-14T00:00:00"],"y":[9],"type":"bar"},{"base":[24],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-21T00:00:00"],"y":[9],"type":"bar"},{"base":[8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-28T00:00:00"],"y":[19],"type":"bar"},{"base":[10],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-07-05T00:00:00"],"y":[12],"type":"bar"},{"base":[8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-07-12T00:00:00"],"y":[12],"type":"bar"},{"base":[9],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-07-19T00:00:00"],"y":[12],"type":"bar"},{"base":[10],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-07-26T00:00:00"],"y":[12],"type":"bar"},{"base":[ ...
