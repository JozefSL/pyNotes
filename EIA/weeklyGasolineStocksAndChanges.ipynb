# %% [markdown]
# <a href="https://colab.research.google.com/github/JozefSL/pyNotes/blob/main/EIA/weeklyGasolineStocksAndChanges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import plotly.express as px
import plotly.graph_objects as go
#import os

# %%
from google.colab import userdata
api_key = userdata.get('api_key')

# %%
url = 'https://api.eia.gov/v2/petroleum/stoc/wstk/data/?api_key='+ api_key + '&data[0]=value&frequency=weekly&start=2014-01-01&sort[0][column]=period&sort[0][direction]=asc&facets[series][]='

# %%
response = requests.get(url + 'WTESTUS1')

# %%
df = pd.DataFrame(response.json().get('response').get('data'))[['period','value']]
df.columns = ['Period', 'value']
df['Period'] = df['Period'].apply(pd.to_datetime)
df.value = (df.value.astype('Int64')/1000).round(1) #.astype('Int64')
df['year'] = df['Period'].dt.year
df['week'] = df['Period'].dt.isocalendar().week
df['change'] = df['value'] - df['value'].shift(1)
df.tail(3)
# Out:
#         Period   value  year  week  change
# 558 2024-09-13  1282.6  2024    37     3.4
# 559 2024-09-20  1268.0  2024    38   -14.6
# 560 2024-09-27  1267.1  2024    39    -0.9

# %%
ty = df.year.iloc[-1]
ly = ty-1

# %%
dfA = df.pivot(index='week', columns='year', values='value').round(1) #.astype('Int64') #.reset_index(drop='true')
dfA = dfA.drop(dfA.index[-1]).reset_index()  #eliminate the add years with 53 weeks

# %%
dfAA = pd.DataFrame(dfA.iloc[:, -6:-1].mean(axis=1))
dfAA.columns = ['5yAvg']
dfAA['5yMin'] = dfA.iloc[:, -6:-1].min(axis=1)
dfAA['5yMaxA'] = dfA.iloc[:, -6:-1].max(axis=1)
dfAA['5yMax'] = dfAA['5yMaxA']-dfAA['5yMin']
dfAA['10yAvg'] = dfA.iloc[:, -11:-1].mean(axis=1)
dfAA['10yMin'] = dfA.iloc[:, -11:-1].min(axis=1)
dfAA['10yMax'] = dfA.iloc[:, -11:-1].max(axis=1)
dfAA['week'] = dfA['week']

# %%
dfA['weekDate'] = pd.to_datetime(str(pd.Timestamp.now().year)+dfA['week'].astype(str)+'5',format='%Y%W%w')
dfAA['weekDate'] = pd.to_datetime(str(pd.Timestamp.now().year)+dfAA['week'].astype(str)+'5',format='%Y%W%w')

# %%
dfAA.head(3)
# Out:
#      5yAvg   5yMin  5yMaxA  5yMax   10yAvg  10yMin  10yMax  week   weekDate
# 0  1255.64  1190.3  1334.3  144.0  1225.21  1025.8  1334.3     1 2024-01-05
# 1  1259.52  1188.8  1333.6  144.8  1226.21  1015.5  1333.6     2 2024-01-12
# 2   1258.1  1184.7  1321.9  137.2   1225.8  1011.6  1338.1     3 2024-01-19

# %%
# Create the area chart
fig = px.area(dfAA, x=dfAA.weekDate, y=['5yMin', '5yMax'], range_y=[1100, 1500], #range_x=[dfAA.index.min()-.2, dfAA.index.max()+.2],
              title='Stacked Area Chart with Line Chart').update_traces(fillcolor='rgba(128, 128, 128, 0.2)')

fig.update_traces(line_color='rgba(0,0,0,0)',showlegend=False)

fig.add_scatter(x=dfAA.weekDate, y=dfAA['5yAvg'], mode='lines', name='5yAvg', line=dict(color='darkgrey', width=2))
fig.add_scatter(x=dfA.weekDate, y=dfA[ly], mode='lines', name=str(ly),line=dict(color='blue', width=2))
fig.add_scatter(x=dfA.weekDate, y=dfA[ty], mode='lines+markers', name=str(ty),line=dict(color='red', width=3), marker=dict(color='red'))

# Customize the chart
fig.update_layout(
    autosize=False,
    width=1200,
    height=800,
    title={
        'text': '<b>Total Petroleum Stocks</b>',
        'font': {'size': 28, 'family': 'Arial', 'color': 'black'}
        },
    xaxis_title='Week',
    yaxis_title='Total Petroleum Stocks (MMbbl)'

)


fig.update_traces(fillcolor='rgba(0,0,0,0)', selector=dict(name='5yMin'))


fig.add_scatter(x = [dfA['weekDate'][dfA[ty].isna().idxmax()-1]], y = [dfA[ty][dfA[ty].isna().idxmax()-1]],
                     mode = 'markers + text',
                     marker = {'color':'red', 'size':14},
                     showlegend = False,
                     text = [dfA[ty][dfA[ty].isna().idxmax()-1]],
                     textfont=dict(color='red', size=16),
                     textposition='bottom right') # top, bottom, middle


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="048db098-6687-4fea-89fa-37d188a78145" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("048db098-6687-4fea-89fa-37d188a78145")) {                    Plotly.newPlot(                        "048db098-6687-4fea-89fa-37d188a78145",                        [{"fillpattern":{"shape":""},"hovertemplate":"variable=5yMin\u003cbr\u003eweekDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5yMin","line":{"color":"rgba(0,0,0,0)"},"marker":{"symbol":"circle"},"mode":"lines","name":"5yMin","orientation":"v","showlegend":false,"stackgroup":"1","x":["2024-01-05T00:00:00","2024-01-12T00:00:00","2024-01-19T00:00:00","2024-01-26T00:00:00","2024-02-02T00:00:00","2024-02-09T00:00:00","2024-02-16T00:00:00","2024-02-23T00:00:00","2024-03-01T00:00:00","2024-03-08T00:00:00","2024-03-15T00:00:00","2024-03-22T00:00:00","2024-03-29T00:00:00","2024-04-05T00:00:00","2024-04-12T00:00:00","2024-04-19T00:00:00","2024-04-26T00:00:00","2024-05-03T00:00:00","2024-05-10T00:00:00","2024-05-17T00:00:00","2024-05-24T00:00:00","2024-05-31T00:00:00","2024-06-07T00:00:00","2024-06-14T00:00:00","2024-06-21T00:00:00","2024-06-28T00:00:00","2024-07-05T00:00:00","2024-07-12T00:00:00","2024-07-19T00:00:00","2024-07-26T00:00:00","2024-08-02T00:00:00","2024-08-09T00:00:00","2024-08-16T00:00:00","2024-08-23T00:00:00","2024-08-30T00:00:00","2024-09-06T00:00:00","2024-09-13T00:00:00","2024-09-20T00:00:00","2024-09-27T00:00:00","2024-10-04T00:00:00","2024-10-11T00:00:00","2024-10-18T00:00:00","2024-
2014  2015  2016  2017  2018  2019  2020  2021  2022  2023  2024
# 49      50   1.2   4.8 -11.9 -14.3 -10.6  -1.1  -6.3  -7.0 -11.6   2.7  <NA>
# 50      51   6.4  -5.2 -13.1  -8.9  -2.2 -10.4 -10.6 -18.9 -11.2 -17.8  <NA>
# 51      52   2.8  -0.1   6.3   1.3  14.4  -3.1 -15.0  10.2  -3.2   6.9  <NA>

# %%
dfAAc = pd.DataFrame(dfAc.iloc[:, -6:-1].mean(axis=1))
dfAAc.columns = ['5yAvg']
dfAAc['5yMin'] = dfAc.iloc[:, -6:-1].min(axis=1) # Actual minimum, also used to calculate stack area bottom
dfAAc['5yMaxA'] = dfAc.iloc[:, -6:-1].max(axis=1) # Actual maximum, also used to calculate stack area top
dfAAc['5yMax'] = dfAAc['5yMaxA']-dfAAc['5yMin']
dfAAc['week'] = dfAc['week']
dfAAc.head(3)
# Out:
#    5yAvg  5yMin  5yMaxA  5yMax  week
# 0   7.26   -9.4    22.4   31.8     1
# 1   3.88   -1.5    14.5   16.0     2
# 2  -1.42  -11.7     6.4   18.1     3

# %%
dfAc['weekDate'] = pd.to_datetime(str(pd.Timestamp.now().year)+dfAc['week'].astype(str)+'5',format='%Y%W%w')
dfAAc['weekDate'] = pd.to_datetime(str(pd.Timestamp.now().year)+dfAAc['week'].astype(str)+'5',format='%Y%W%w')

# %%
categories = dfAAc['weekDate']
lower_bounds = dfAAc['5yMin']
upper_bounds = dfAAc['5yMaxA']

# %%
fig = go.Figure()

for i in range(len(categories)):
    fig.add_trace(go.Bar(
        x=[categories[i]],
        y=[upper_bounds[i] - lower_bounds[i]],
        base=[lower_bounds[i]],
        marker=dict(color='lightgrey'),
        showlegend=False
        #color_discrete_sequence=['blue']
        #name=str(categories[i])
    ))

fig.add_scatter(x=dfAAc.weekDate, y=dfAAc['5yAvg'], mode='markers', name='5yAvg', line=dict(color='grey', width=2))
fig.add_scatter(x=dfAc.weekDate, y=dfAc[ly], mode='markers', name=str(ly),line=dict(color='blue', width=2))
fig.add_scatter(x=dfAc.weekDate, y=dfAc[ty], mode='lines+markers', name=str(ty),line=dict(color='red', width=3), marker=dict(color='red'))

fig.add_scatter(x = [dfAc['weekDate'][dfAc[ty].isna().idxmax()-1]], y = [dfAc[ty][dfAc[ty].isna().idxmax()-1]],
                     mode = 'markers + text',
                     marker = {'color':'red', 'size':14},
                     showlegend = False,
                     text = [dfAc[ty][dfAc[ty].isna().idxmax()-1]],
                     textfont=dict(color='red', size=16),
                     textposition='top center') # top left, bottom right, middle left, bottom righ, top center, auto center

fig.update_layout(autosize=False,width=1200, height=700,
    title={
        'text': '<b>Total Petroleum Stocks Weekly Changes</b>',
        'font': {'size': 28, 'family': 'Arial', 'color': 'black'}
        },
    #xaxis_title='Week',
    yaxis_title='Total Petroleum Stocks Weekly Change (MMbbl)')

# Add source link as an annotation
fig.add_annotation(
    text="Source: EIA     https://www.eia.gov/petroleum/supply/weekly",
    xref="paper", yref="paper",
    x=0.95, y=0.05,
    showarrow=False,
    font=dict(size=13)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="941ea677-c73b-45e8-acbc-e839a75d8ab8" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("941ea677-c73b-45e8-acbc-e839a75d8ab8")) {                    Plotly.newPlot(                        "941ea677-c73b-45e8-acbc-e839a75d8ab8",                        [{"base":[-9.4],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-05T00:00:00"],"y":[31.799999999999997],"type":"bar"},{"base":[-1.5],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-12T00:00:00"],"y":[16.0],"type":"bar"},{"base":[-11.7],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-19T00:00:00"],"y":[18.1],"type":"bar"},{"base":[-5.8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-01-26T00:00:00"],"y":[8.7],"type":"bar"},{"base":[-11.2],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-02T00:00:00"],"y":[14.6],"type":"bar"},{"base":[-15.0],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-09T00:00:00"],"y":[34.2],"type":"bar"},{"base":[-13.8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-16T00:00:00"],"y":[17.1],"type":"bar"},{"base":[-18.1],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-02-23T00:00:00"],"y":[16.1],"type":"bar"},{"base":[-11.8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-01T00:00:00"],"y":[13.600000000000001],"type":"bar"},{"base":[-10.0],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-08T00:00:00"],"y":[13.6],"type":"bar"},{"base":[-12.5],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-15T00:00:00"],"y":[17.3],"type":"bar"},{"base":[-10.7],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-22T00:00:00"],"y":[13.0],"type":"bar"},{"base":[-11.1],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-03-29T00:00:00"],"y":[32.1],"type":"bar"},{"base":[-9.0],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-05T00:00:00"],"y":[42.0],"type":"bar"},{"base":[-8.1],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-12T00:00:00"],"y":[35.4],"type":"bar"},{"base":[-1.6],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-19T00:00:00"],"y":[27.1],"type":"bar"},{"base":[-5.6],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-04-26T00:00:00"],"y":[18.7],"type":"bar"},{"base":[-1.8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-03T00:00:00"],"y":[19.7],"type":"bar"},{"base":[-2.9],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-10T00:00:00"],"y":[17.7],"type":"bar"},{"base":[-10.8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-17T00:00:00"],"y":[27.6],"type":"bar"},{"base":[-1.3],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-24T00:00:00"],"y":[16.2],"type":"bar"},{"base":[10.9],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-05-31T00:00:00"],"y":[11.9],"type":"bar"},{"base":[-4.6],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-07T00:00:00"],"y":[16.799999999999997],"type":"bar"},{"base":[-5.8],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-14T00:00:00"],"y":[12.899999999999999],"type":"bar"},{"base":[-11.9],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-21T00:00:00"],"y":[18.2],"type":"bar"},{"base":[-9.9],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-06-28T00:00:00"],"y":[15.100000000000001],"type":"bar"},{"base":[-3.6],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-07-05T00:00:00"],"y":[25.3],"type":"bar"},{"base":[-9.3],"marker":{"color":"lightgrey"},"showlegend":false,"x":["2024-07-12T00:00:00"],"y":[21.3],"type":"bar"},{"base":[-6.5],"marker":{"color":"lightgrey"},"sh ...
