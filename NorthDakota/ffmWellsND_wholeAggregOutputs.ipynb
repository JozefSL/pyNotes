# %%
import requests
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
# create list of all yyyy-mm for data download (Note, May 2015 is the first month ND data is available in xlxs)
myList = pd.date_range('2015-04-10',datetime.today()- relativedelta(months=2), freq='MS').strftime("%Y_%m").tolist()  # with month in numeric format

# Access the ND DMR data @ https://www.dmr.nd.gov/oilgas/mprindex.asp
website = "https://www.dmr.nd.gov/oilgas/mpr/"

# %%
# Review the list of monthly data
myList

# %%
NDMWD = []  #list()  # North Dakota Monthly Well (NDMWD) Data download process ~ 10 minutes
for month in myList:
    target_url = website + month + '.xlsx'
    print(target_url)
    r = requests.get(target_url)
    wb = pd.read_excel(r.content)
    NDMWD.append(wb)

NDMWD = pd.concat(NDMWD)
# Out:
# https://www.dmr.nd.gov/oilgas/mpr/2015_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2015_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2016_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2017_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2018_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2019_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2020_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2021_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_06.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_07.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_08.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_09.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_10.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_11.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2022_12.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2023_01.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2023_02.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2023_03.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2023_04.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2023_05.xlsx
# https://www.dmr.nd.gov/oilgas/mpr/2023_06.xlsx

# %%
#Create ND monthly well data table in csv format, which can be downloaded from folder on left hand side
NDMWD.to_csv('NDMWD.csv', index=False)

# %%
NDMWD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1706085 entries, 0 to 20182
# Data columns (total 21 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ReportDate  datetime64[ns]
#  1   API_WELLNO  int64
#  2   FileNo      int64
#  3   Company     object
#  4   WellName    object
#  5   Quarter     object
#  6   Section     float64
#  7   Township    float64
#  8   Range       float64
#  9   County      object
#  10  FieldName   object
#  11  Pool        object
#  12  Oil         float64
#  13  Wtr         float64
#  14  Days        float64
#  15  Runs        int64
#  16  Gas         float64
#  17  GasSold     int64
#  18  Flared      float64
#  19  Lat         float64
#  20  Long        float64
# dtypes: datetime64[ns](1), float64(10), int64(4), object(6)
# memory usage: 286.4+ MB

# %% [markdown]
# # **Extract first month oil and gas produciton**

# %%
#NDMWD = pd.read_csv('NDMWD.csv')
NDMWD.drop_duplicates(inplace=True)
NDMWD = NDMWD[NDMWD['Days'] >= 25].reset_index(drop=True)
NDMWD['ReportDate'] = pd.to_datetime(NDMWD['ReportDate'], errors = 'coerce')
NDMWD.tail(2)
# Out:
#         ReportDate      API_WELLNO  FileNo                  Company WellName  \
# 1234977 2023-06-01  33009012640000    6347  EMPIRE NORTH DAKOTA LLC   RICE 2
# 1234978 2023-06-01  33009019570000   13685  EMPIRE NORTH DAKOTA LLC   RICE 3
#
#         Quarter  Section  Township  Range County  ...               Pool  \
# 1234977    SENW     26.0     163.0   79.0    BOT  ...  SPEARFISH/MADISON
# 1234978    NENW     26.0     163.0   79.0    BOT  ...  SPEARFISH/MADISON
#
#           Oil     Wtr  Days  Runs  Gas  GasSold  Flared        Lat        Long
# 1234977  25.0   268.0  30.0     0  0.0        0     0.0  48.917191 -100.876462
# 1234978  51.0  6565.0  30.0     0  0.0        0     0.0  48.920808 -100.877109
#
# [2 rows x 21 columns]

# %%
ffmWells = NDMWD[['API_WELLNO', 'Pool','ReportDate']].groupby('API_WELLNO').min().rename(columns={'ReportDate':'ffMonth'}).reset_index()
ffmWells.tail(3)
# Out:
#            API_WELLNO     Pool    ffMonth
# 20439  33105058760000   BAKKEN 2023-05-01
# 20440  33105061150000  MADISON 2023-06-01
# 20441  33105903870000   DAKOTA 2018-01-01

# %%
ffmWells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20442 entries, 0 to 20441
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  20442 non-null  int64
#  1   Pool        20442 non-null  object
#  2   ffMonth     20442 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 479.2+ KB

# %%
ffmWells = ffmWells.merge(NDMWD[['API_WELLNO','Pool','ReportDate','Oil','Gas','Wtr','Days','Runs', 'Lat', 'Long']], how='left', left_on=['API_WELLNO','Pool','ffMonth'], right_on = ['API_WELLNO','Pool','ReportDate'])
ffmWells.dropna(inplace=True)
ffmWells.reset_index(drop=True)
ffmWells.tail()
# Out:
#            API_WELLNO     Pool    ffMonth ReportDate      Oil      Gas  \
# 20437  33105058570000   BAKKEN 2023-05-01 2023-05-01  26701.0  24497.0
# 20438  33105058750000   BAKKEN 2023-03-01 2023-03-01  40250.0  31819.0
# 20439  33105058760000   BAKKEN 2023-05-01 2023-05-01  31521.0  26441.0
# 20440  33105061150000  MADISON 2023-06-01 2023-06-01    938.0     27.0
# 20441  33105903870000   DAKOTA 2018-01-01 2018-01-01    410.0      0.0
#
#            Wtr  Days     Runs        Lat        Long
# 20437  64246.0  31.0  26751.0  48.167755 -103.719029
# 20438  93444.0  25.0  39436.0  48.169415 -103.699984
# 20439  69949.0  31.0  31478.0  48.169418 -103.700107
# 20440    686.0  30.0   1282.0  48.016557 -103.859187
# 20441      0.0  31.0    946.0  48.404169 -103.475385

# %%
ffmWells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20412 entries, 0 to 20441
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  20412 non-null  int64
#  1   Pool        20412 non-null  object
#  2   ffMonth     20412 non-null  datetime64[ns]
#  3   ReportDate  20412 non-null  datetime64[ns]
#  4   Oil         20412 non-null  float64
#  5   Gas         20412 non-null  float64
#  6   Wtr         20412 non-null  float64
#  7   Days        20412 non-null  float64
#  8   Runs        20412 non-null  float64
#  9   Lat         20412 non-null  float64
#  10  Long        20412 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(1)
# memory usage: 1.9+ MB

# %%
ffmWells.drop('ReportDate', axis=1, inplace=True )
ffmWells['bpd'] =  ffmWells.Oil/ffmWells.Days
ffmWells['Mcfpd'] =  ffmWells.Gas/ffmWells.Days

# %%
ffmWells.tail()
# Out:
#            API_WELLNO     Pool    ffMonth      Oil      Gas      Wtr  Days  \
# 20437  33105058570000   BAKKEN 2023-05-01  26701.0  24497.0  64246.0  31.0
# 20438  33105058750000   BAKKEN 2023-03-01  40250.0  31819.0  93444.0  25.0
# 20439  33105058760000   BAKKEN 2023-05-01  31521.0  26441.0  69949.0  31.0
# 20440  33105061150000  MADISON 2023-06-01    938.0     27.0    686.0  30.0
# 20441  33105903870000   DAKOTA 2018-01-01    410.0      0.0      0.0  31.0
#
#           Runs        Lat        Long          bpd        Mcfpd
# 20437  26751.0  48.167755 -103.719029   861.322581   790.225806
# 20438  39436.0  48.169415 -103.699984  1610.000000  1272.760000
# 20439  31478.0  48.169418 -103.700107  1016.806452   852.935484
# 20440   1282.0  48.016557 -103.859187    31.266667     0.900000
# 20441    946.0  48.404169 -103.475385    13.225806     0.000000

# %%
ffmWells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20412 entries, 0 to 20441
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API_WELLNO  20412 non-null  int64
#  1   Pool        20412 non-null  object
#  2   ffMonth     20412 non-null  datetime64[ns]
#  3   Oil         20412 non-null  float64
#  4   Gas         20412 non-null  float64
#  5   Wtr         20412 non-null  float64
#  6   Days        20412 non-null  float64
#  7   Runs        20412 non-null  float64
#  8   Lat         20412 non-null  float64
#  9   Long        20412 non-null  float64
#  10  bpd         20412 non-null  float64
#  11  Mcfpd       20412 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 2.0+ MB

# %% [markdown]
# # **Wells to MHB allocation**

# %%
# Maidenhead grid locators courtesy of Walter Underwood K6WRU:
# https://ham.stackexchange.com/questions/221/how-can-one-convert-from-lat-long-to-grid-square

# %%
upper = 'ABCDEFGHIJKLMNOPQRSTUVWX'
lower = 'abcdefghijklmnopqrstuvwx'

# %%
def gridCalc(row):
    dec_lat = row['Lat']
    dec_lon = row['Long']
    if not (-180<=dec_lon<180):
        sys.stderr.write('longitude must be -180<=lon<180, given %f\n'%dec_lon)
        sys.exit(32)
    if not (-90<=dec_lat<90):
        sys.stderr.write('latitude must be -90<=lat<90, given %f\n'%dec_lat)
        sys.exit(33) # can't handle north pole, sorry, [A-R]

    adj_lat = dec_lat + 90.0
    adj_lon = dec_lon + 180.0

    grid_lat_sq = upper[int(adj_lat/10)];
    grid_lon_sq = upper[int(adj_lon/20)];

    grid_lat_field = str(int(adj_lat%10))
    grid_lon_field = str(int((adj_lon/2)%10))

    adj_lat_remainder = (adj_lat - int(adj_lat)) * 60
    adj_lon_remainder = ((adj_lon) - int(adj_lon/2)*2) * 60

    grid_lat_subsq = lower[int(adj_lat_remainder/2.5)]
    grid_lon_subsq = lower[int(adj_lon_remainder/5)]

    return grid_lon_sq + grid_lat_sq + grid_lon_field + grid_lat_field + grid_lon_subsq + grid_lat_subsq

# %%
ffmWells['MHB'] = ffmWells.apply(gridCalc, axis=1)

# %%
ffmWells.tail()
# Out:
#            API_WELLNO     Pool    ffMonth      Oil      Gas      Wtr  Days  \
# 20437  33105058570000   BAKKEN 2023-05-01  26701.0  24497.0  64246.0  31.0
# 20438  33105058750000   BAKKEN 2023-03-01  40250.0  31819.0  93444.0  25.0
# 20439  33105058760000   BAKKEN 2023-05-01  31521.0  26441.0  69949.0  31.0
# 20440  33105061150000  MADISON 2023-06-01    938.0     27.0    686.0  30.0
# 20441  33105903870000   DAKOTA 2018-01-01    410.0      0.0      0.0  31.0
#
#           Runs        Lat        Long          bpd        Mcfpd     MHB
# 20437  26751.0  48.167755 -103.719029   861.322581   790.225806  DN88de
# 20438  39436.0  48.169415 -103.699984  1610.000000  1272.760000  DN88de
# 20439  31478.0  48.169418 -103.700107  1016.806452   852.935484  DN88de
# 20440   1282.0  48.016557 -103.859187    31.266667     0.900000  DN88ba
# 20441    946.0  48.404169 -103.475385    13.225806     0.000000  DN88gj

# %%
ffmWells.to_csv('ffmWells.csv', index=False)

# %% [markdown]
# # **Read and combine files**

# %%
ffmWells = pd.read_csv('ffmWells.csv')

# %%
llWells = pd.read_csv('llWells.csv')

# %%
ffmWells.tail()
# Out:
#            API_WELLNO     Pool     ffMonth      Oil      Gas      Wtr  Days  \
# 20407  33105058570000   BAKKEN  2023-05-01  26701.0  24497.0  64246.0  31.0
# 20408  33105058750000   BAKKEN  2023-03-01  40250.0  31819.0  93444.0  25.0
# 20409  33105058760000   BAKKEN  2023-05-01  31521.0  26441.0  69949.0  31.0
# 20410  33105061150000  MADISON  2023-06-01    938.0     27.0    686.0  30.0
# 20411  33105903870000   DAKOTA  2018-01-01    410.0      0.0      0.0  31.0
#
#           Runs        Lat        Long          bpd        Mcfpd     MHB
# 20407  26751.0  48.167755 -103.719029   861.322581   790.225806  DN88de
# 20408  39436.0  48.169415 -103.699984  1610.000000  1272.760000  DN88de
# 20409  31478.0  48.169418 -103.700107  1016.806452   852.935484  DN88de
# 20410   1282.0  48.016557 -103.859187    31.266667     0.900000  DN88ba
# 20411    946.0  48.404169 -103.475385    13.225806     0.000000  DN88gj

# %%
llWells.tail()
# Out:
#            api_wellno well_sub        totll
# 43582  33105902990000     VERT    11.046069
# 43583  33105904500000     LAT1  1787.417830
# 43584  33105904500000     VERT    26.586334
# 43585  33105904660000     LAT1  2305.694952
# 43586  33105904660000     VERT     9.541455

# %%
llWellsLat1 = llWells[llWells['well_sub'] == 'LAT1'].reset_index(drop=True)
llWellsLat1.tail()
# Out:
#            api_wellno well_sub         totll
# 19904  33105060500000     LAT1  10745.854055
# 19905  33105060730000     LAT1    545.682062
# 19906  33105902990000     LAT1   2102.817016
# 19907  33105904500000     LAT1   1787.417830
# 19908  33105904660000     LAT1   2305.694952

# %%
ffmWells = ffmWells.merge(llWellsLat1, how = 'left', left_on = 'API_WELLNO', right_on = 'api_wellno')

# %%
ffmWells.tail()
# Out:
#            API_WELLNO     Pool     ffMonth      Oil      Gas      Wtr  Days  \
# 20407  33105058570000   BAKKEN  2023-05-01  26701.0  24497.0  64246.0  31.0
# 20408  33105058750000   BAKKEN  2023-03-01  40250.0  31819.0  93444.0  25.0
# 20409  33105058760000   BAKKEN  2023-05-01  31521.0  26441.0  69949.0  31.0
# 20410  33105061150000  MADISON  2023-06-01    938.0     27.0    686.0  30.0
# 20411  33105903870000   DAKOTA  2018-01-01    410.0      0.0      0.0  31.0
#
#           Runs        Lat        Long          bpd        Mcfpd     MHB  \
# 20407  26751.0  48.167755 -103.719029   861.322581   790.225806  DN88de
# 20408  39436.0  48.169415 -103.699984  1610.000000  1272.760000  DN88de
# 20409  31478.0  48.169418 -103.700107  1016.806452   852.935484  DN88de
# 20410   1282.0  48.016557 -103.859187    31.266667     0.900000  DN88ba
# 20411    946.0  48.404169 -103.475385    13.225806     0.000000  DN88gj
#
#          api_wellno well_sub         totll
# 20407  3.310506e+13     LAT1  10753.179882
# 20408  3.310506e+13     LAT1  10729.605131
# 20409  3.310506e+13     LAT1  10727.102474
# 20410           NaN      NaN           NaN
# 20411           NaN      NaN           NaN

# %%
ffWellsND = pd.read_csv('ffWellsND.csv')
ffWellsND.drop('Unnamed: 0', inplace=True, axis=1)
ffWellsND.tail()
# Out:
#             APINumber  JobEndDate  TotalBaseWaterVolume      SandLB
# 16088  33025041590000  2023-08-12             5686172.0  8841309.84
# 16089  33025034420000  2023-08-12             5680525.0  6012038.00
# 16090  33025034470000  2023-08-13             6166909.0  6541850.00
# 16091  33025046910000  2023-08-13             7494120.0  8521120.00
# 16092  33025046920000  2023-08-13             7266037.0  8522543.00

# %%
ffWellsND = ffWellsND.sort_values(['APINumber','JobEndDate']).reset_index(drop = True)
ffWellsND["sfID"] = ffWellsND.groupby(['APINumber']).cumcount()
ffWellsND.tail()
# Out:
#             APINumber  JobEndDate  TotalBaseWaterVolume       SandLB  sfID
# 16088  33105059720000  2023-05-06           11151006.72          NaN     0
# 16089  33105059730000  2023-05-06           10978190.58          NaN     0
# 16090  33105121850000  2012-02-24                   NaN          NaN     0
# 16091  33610338000000  2022-06-08           13496802.00  10357262.37     0
# 16092  33610338100000  2022-06-09           14820967.00  11223894.87     0

# %%
ffWellsFF = ffWellsND[ffWellsND['sfID']==0].reset_index(drop = True)
ffWellsFF.tail()
# Out:
#             APINumber  JobEndDate  TotalBaseWaterVolume       SandLB  sfID
# 15136  33105059720000  2023-05-06           11151006.72          NaN     0
# 15137  33105059730000  2023-05-06           10978190.58          NaN     0
# 15138  33105121850000  2012-02-24                   NaN          NaN     0
# 15139  33610338000000  2022-06-08           13496802.00  10357262.37     0
# 15140  33610338100000  2022-06-09           14820967.00  11223894.87     0

# %%
ffWellsFF.drop('sfID', inplace=True, axis=1)
ffWellsFF.tail()
# Out:
#             APINumber  JobEndDate  TotalBaseWaterVolume       SandLB
# 15136  33105059720000  2023-05-06           11151006.72          NaN
# 15137  33105059730000  2023-05-06           10978190.58          NaN
# 15138  33105121850000  2012-02-24                   NaN          NaN
# 15139  33610338000000  2022-06-08           13496802.00  10357262.37
# 15140  33610338100000  2022-06-09           14820967.00  11223894.87

# %%
ffmWells = ffmWells.merge(ffWellsFF, how = 'left', left_on = 'API_WELLNO', right_on = 'APINumber')
ffmWells.tail()
# Out:
#            API_WELLNO     Pool     ffMonth      Oil      Gas      Wtr  Days  \
# 20407  33105058570000   BAKKEN  2023-05-01  26701.0  24497.0  64246.0  31.0
# 20408  33105058750000   BAKKEN  2023-03-01  40250.0  31819.0  93444.0  25.0
# 20409  33105058760000   BAKKEN  2023-05-01  31521.0  26441.0  69949.0  31.0
# 20410  33105061150000  MADISON  2023-06-01    938.0     27.0    686.0  30.0
# 20411  33105903870000   DAKOTA  2018-01-01    410.0      0.0      0.0  31.0
#
#           Runs        Lat        Long          bpd        Mcfpd     MHB  \
# 20407  26751.0  48.167755 -103.719029   861.322581   790.225806  DN88de
# 20408  39436.0  48.169415 -103.699984  1610.000000  1272.760000  DN88de
# 20409  31478.0  48.169418 -103.700107  1016.806452   852.935484  DN88de
# 20410   1282.0  48.016557 -103.859187    31.266667     0.900000  DN88ba
# 20411    946.0  48.404169 -103.475385    13.225806     0.000000  DN88gj
#
#          api_wellno well_sub         totll     APINumber  JobEndDate  \
# 20407  3.310506e+13     LAT1  10753.179882  3.310506e+13  2023-01-27
# 20408  3.310506e+13     LAT1  10729.605131  3.310506e+13  2023-02-15
# 20409  3.310506e+13     LAT1  10727.102474  3.310506e+13  2023-02-15
# 20410           NaN      NaN           NaN           NaN         NaN
# 20411           NaN      NaN           NaN           NaN         NaN
#
#        TotalBaseWaterVolume       SandLB
# 20407            11088845.0  10028631.33
# 20408            10865393.0  10498341.15
# 20409            10332110.0  10058611.32
# 20410                   NaN          NaN
# 20411                   NaN          NaN

# %%
ffmWells.to_csv('ND_Data.csv')
